# %% [markdown]
# ####
# We should put some if clauses such that if contract expires or there is a release clause our prediction is not made by the model, but we already know the transfer value
# ###

# %%
import pandas as pd
import numpy as np
from collections import Counter
from sklearn.preprocessing import OneHotEncoder
import os
import glob
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import LassoCV
from sklearn.ensemble  import RandomForestRegressor
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
from xgboost import XGBRegressor
import pickle
from tqdm import tqdm

# import k-Means
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
# read files
from pathlib import Path
path = str(Path("andrea_models.ipynb").parent.absolute().parent.absolute()) + "/data/Final/ratings"
csv_files = glob.glob(os.path.join(path, "*.csv"))

# create one dataframe with ratings_20.csv and ratings_21.csv (train_valid dataframe), and one with ratings_22.csv (test dataframe)
train_valid = pd.concat([pd.read_csv(f) for f in csv_files[1:3]], ignore_index = True)
test = pd.read_csv(csv_files[0])

# %%
# save player_name in a variable
short_name_train_valid = train_valid["short_name"]
short_name_test = test["short_name"]

# drop the columns that are not needed
unnecessary_columns = ["short_name", "club_name", "year", "release_clause_eur"]
train_valid = train_valid.drop(unnecessary_columns, axis = 1)
test = test.drop(unnecessary_columns, axis = 1)

# divide value_eur and release_clause_eur by 1000000
train_valid["value_eur"] = train_valid["value_eur"]/1000000
#train_valid["release_clause_eur"] = train_valid["release_clause_eur"]/1000000
test["value_eur"] = test["value_eur"]/1000000
#test["release_clause_eur"] = test["release_clause_eur"]/1000000

# print them in new csv so we can use them in the other notebook
train_valid.to_csv("train_valid.csv", index = False)
test.to_csv("test.csv", index = False)

# define target and features
target = "value_eur"
features = [col for col in train_valid.columns if col != target]

# split into X and y
X_train_valid = train_valid[features]
y_train_valid = train_valid[target]

X_test = test[features]
y_test = test[target]

# %% [markdown]
# ## Data pre-processing: fees and release clauses

# %%
# shapes of the datasets
print("train_valid shape: ", train_valid.shape)
print("test shape: ", test.shape)
# Out:
# train_valid shape:  (34749, 60)
# test shape:  (18063, 60)

# %%
# display all columns
pd.set_option('display.max_columns', None)
X_train_valid.head()
# Out:
#    overall  potential  wage_eur  age  height_cm  weight_kg  league_level  \
# 0       93         93  560000.0   33        170         72           1.0
# 1       92         92  220000.0   35        187         83           1.0
# 2       91         91  240000.0   31        184         80           1.0
# 3       91         91  270000.0   28        175         68           1.0
# 4       91         91  370000.0   29        181         70           1.0
#
#    club_joined  club_contract_valid_until  preferred_foot  weak_foot  \
# 0         2004                     2021.0               0          4
# 1         2004                     2022.0               1          4
# 2         2004                     2023.0               1          4
# 3         2004                     2022.0               1          5
# 4         2004                     2023.0               1          5
#
#    skill_moves  international_reputation  pace  shooting  passing  dribbling  \
# 0            4                         5  85.0      92.0     91.0       95.0
# 1            5                         5  89.0      93.0     81.0       89.0
# 2            4                         4  78.0      91.0     78.0       85.0
# 3            5                         5  91.0      85.0     86.0       94.0
# 4            4                         4  76.0      86.0     93.0       88.0
#
#    defending  physic  attacking_crossing  attacking_finishing  \
# 0       38.0    65.0                  85                   95
# 1       35.0    77.0                  84                   95
# 2       43.0    82.0                  71                   94
# 3       36.0    59.0                  85                   87
# 4       64.0    78.0                  94                   82
#
#    attacking_heading_accuracy  attacking_short_passing  attacking_volleys  \
# 0                          70                       91                 88
# 1                          90                       82                 86
# 2                          85                       84                 89
# 3                          62                       87                 87
# 4                          55                       94                 82
#
#    skill_dribbling  skill_curve  skill_fk_accuracy  skill_long_passing  \
# 0               96           93                 94                  91
# 1               88           81                 76                  77
# 2               85           79                 85                  70
# 3               95           88                 89                  81
# 4               88           85                 83                  93
#
#    skill_ball_control  movement_acceleration  movement_sprint_speed  \
# 0                  96                     91                     80
# 1                  92                     87                     91
# 2                  88                     77                     78
# 3                  95                     94                     89
# 4                  92                     77                     76
#
#    movement_agility  movement_reactions  movement_balance  power_shot_power  \
# 0                91                  94                95                86
# 1                87                  95                71                94
# 2                77                  93                82                89
# 3                96                  91                83                80
# 4                78                  91                76                91
#
#    power_jumping  power_stamina  power_strength  power_long_shots  \
# 0             68             72              69                94
# 1             95             84              78                93
# 2             84             76              86                85
# 3             62             81              50                84
# 4             63             89              74                91
#
#    mentality_aggression  mentality_interceptions  mentality_positioning  \
# 0                    44                       40                     93
# 1                    63                       29                     95
# 2                    81                       49                     94
# 3                    51                       36                     87
# 4                    76                       66                     88
#
#    mentality_vision  mentality_penalties  mentality_composure  \
# 0                95                   75                   96
# 1                82                   84                   95
# 2                79                   88                   88
# 3                90                   92                   93
# 4                94                   84                   91
#
#    defending_marking_awareness  defending_standing_tackle  \
# 0                           32                         35
# 1                           28                         32
# 2                           35                         42
# 3                           35                         30
# 4                           68                         65
#
#    defending_sliding_tackle  goalkeeping_diving  goalkeeping_handling  \
# 0                        24                   6                    11
# 1                        24                   7                    11
# 2                        19                  15                     6
# 3                        29                   9                     9
# 4                        53                  15                    13
#
#    goalkeeping_kicking  goalkeeping_positioning  goalkeeping_reflexes  \
# 0                   15                       14                     8
# 1                   15                       14                    11
# 2                   12                        8                    10
# 3                   15                       15                    11
# 4                    5                       10                    13
#
#    position_A  position_M  position_D  position_G  attack_work_rate  \
# 0           1           1           0           0                 2
# 1           1           0           0           0                 3
# 2           1           0           0           0                 3
# 3           1           1           0           0                 3
# 4           0           1           0           0                 3
#
#    defense_work_rate
# 0                  1
# 1                  1
# 2                  2
# 3                  2
# 4                  3

# %%
# correlation between features and target
corr = train_valid.corr()
corr["value_eur"].sort_values(ascending = False)
# Out:
# value_eur                      1.000000
# wage_eur                       0.817525
# overall                        0.583161
# international_reputation       0.565231
# potential                      0.551887
# movement_reactions             0.514842
# passing                        0.421010
# mentality_composure            0.415679
# dribbling                      0.407017
# mentality_vision               0.339484
# power_shot_power               0.323885
# shooting                       0.314402
# attacking_short_passing        0.307284
# skill_long_passing             0.289226
# skill_ball_control             0.282221
# skill_moves                    0.277594
# skill_curve                    0.266570
# attacking_volleys              0.255026
# skill_dribbling                0.250442
# power_long_shots               0.250019
# attacking_crossing             0.236996
# mentality_positioning          0.236783
# skill_fk_accuracy              0.231119
# attacking_finishing            0.228680
# physic                         0.220785
# mentality_penalties            0.209020
# power_stamina                  0.205333
# club_contract_valid_until      0.192854
# mentality_aggression           0.184294
# pace                           0.182376
# movement_agility               0.180148
# attacking_heading_accuracy     0.172168
# movement_sprint_speed          0.167850
# movement_acceleration          0.162817
# weak_foot                      0.155618
# defending                      0.153424
# defending_marking_awareness    0.146866
# mentality_interceptions        0.145545
# attack_work_rate               0.135658
# power_strength                 0.129038
# power_jumping                  0.123706
# defending_standing_tackle      0.120578
# movement_balance               0.116594
# defending_sliding_tackle       0.101023
# defense_work_rate              0.065298
# age                            0.058457
# position_M                     0.046866
# position_A                     0.045198
# weight_kg                      0.040465
# height_cm                      0.006259
# goalkeeping_positioning       -0.014986
# goalkeeping_reflexes          -0.015157
# goalkeeping_handling          -0.015797
# goalkeeping_diving            -0.016599
# goalkeeping_kicking           -0.017184
# preferred_foot                -0.019598
# position_D                    -0.036896
# position_G                    -0.040176
# league_level                  -0.134666
# club_joined                         NaN
# Name: value_eur, dtype: float64

# %%
# show how many value_eur are less than 1
train_valid[train_valid["value_eur"] < 1].shape
test[test["value_eur"] < 1].shape
# Out:
# (9334, 60)

# %%
# goalkeepers
train_valid[train_valid["position_G"] == 1].head()
# Out:
#     overall  potential  value_eur  wage_eur  age  height_cm  weight_kg  \
# 5        91         93      120.0  125000.0   27        188         87
# 6        90         93      110.0  260000.0   28        187         85
# 10       90         91      102.0  160000.0   27        191         91
# 15       89         89       17.5  130000.0   34        193         92
# 16       89         90       82.0  250000.0   28        199         96
#
#     league_level  club_joined  club_contract_valid_until  preferred_foot  \
# 5            1.0         2004                     2023.0               1
# 6            1.0         2004                     2022.0               1
# 10           1.0         2004                     2024.0               1
# 15           1.0         2004                     2023.0               1
# 16           1.0         2004                     2024.0               0
#
#     weak_foot  skill_moves  international_reputation  pace  shooting  passing  \
# 5           3            1                         3   NaN       NaN      NaN
# 6           4            1                         3   NaN       NaN      NaN
# 10          3            1                         3   NaN       NaN      NaN
# 15          4            1                         5   NaN       NaN      NaN
# 16          3            1                         4   NaN       NaN      NaN
#
#     dribbling  defending  physic  attacking_crossing  attacking_finishing  \
# 5         NaN        NaN     NaN                  13                   11
# 6         NaN        NaN     NaN                  18                   14
# 10        NaN        NaN     NaN                  17                   13
# 15        NaN        NaN     NaN                  15                   13
# 16        NaN        NaN     NaN                  14                   14
#
#     attacking_heading_accuracy  attacking_short_passing  attacking_volleys  \
# 5                           15                       43                 13
# 6                           11                       61                 14
# 10                          19                       45                 20
# 15                          25                       55                 11
# 16                          13                       33                 12
#
#     skill_dribbling  skill_curve  skill_fk_accuracy  skill_long_passing  \
# 5                12           13                 14                  40
# 6                21           18                 12                  63
# 10               27           19                 18                  44
# 15               30           14                 11                  59
# 16               13           19                 20                  35
#
#     skill_ball_control  movement_acceleration  movement_sprint_speed  \
# 5                   30                     43                     60
# 6                   30                     38                     50
# 10                  30                     56                     47
# 15                  46                     54                     60
# 16                  23                     42                     52
#
#     movement_agility  movement_reactions  movement_balance  power_shot_power  \
# 5                 67                  88                49                59
# 6                 37                  86                43                66
# 10                40                  88                37                64
# 15                51                  86                35                68
# 16                61                  84                45                56
#
#     power_jumping  power_stamina  power_strength  power_long_shots  \
# 5              78             41              78                12
# 6              79             35              78                10
# 10             52             32              78                14
# 15             77             43              80                16
# 16             68             38              70                17
#
#     mentality_aggression  mentality_interceptions  mentality_positioning  \
# 5                     34                       19                     11
# 6                     43                       22                     11
# 10                    27                       11                     13
# 15                    29                       30                     12
# 16                    23                       15                     13
#
#     mentality_vision  mentality_penalties  mentality_composure  \
# 5                 65                   11                   68
# 6                 70                   25                   70
# 10                66                   23                   65
# 15                70                   47                   70
# 16                44                   27                   66
#
#     defending_marking_awareness  defending_standing_tackle  \
# 5                            27                         12
# 6                            25                         13
# 10                           15                         19
# 15                           17                         10
# 16                           20                         18
#
#     defending_sliding_tackle  goalkeeping_diving  goalkeeping_handling  \
# 5                         18                  87                    92
# 6                         10                  88                    85
# 10                        16                  86                    88
# 15                        11                  87                    87
# 16                        16                  84                    89
#
#     goalkeeping_kicking  goalkeeping_positioning  goalkeeping_reflexes  \
# 5                    78                       90                    90
# 6                    88                       88                    90
# 10                   85                       91                    89
# 15                   91                       86                    89
# 16                   74                       85                    88
#
#     position_A  position_M  position_D  position_G  attack_work_rate  \
# 5            0           0           0           1                 2
# 6            0           0           0           1                 2
# 10           0           0           0           1                 2
# 15           0           0           0           1                 2
# 16           0           0           0           1                 2
#
#     defense_work_rate
# 5                   2
# 6                   2
# 10                  2
# 15                  2
# 16                  2

# %% [markdown]
# ## Define functions that will be used across models

# %%
def compute_results(y_pred, y_true):
    """
    Compute the results of the model
    """
    # compute the mean absolute error
    mae = np.mean(abs(y_pred - y_true))
    
    # compute the mean squared error
    mse = np.mean((y_pred - y_true) ** 2)
    
    # compute the root mean squared error
    rmse = np.sqrt(mse)
    
    # compute the mean absolute percentage error
    mape = np.mean(abs((y_pred - y_true) / y_true))
    
    # compute the coefficient of determination
    r2 = 1 - (np.sum((y_pred - y_true) ** 2) / np.sum((y_true - np.mean(y_true)) ** 2))
    
    # store the results in a dataframe
    results = pd.DataFrame({"mae": [mae], "mse": [mse], "rmse": [rmse], "mape": [mape], "r2": [r2]})

    return results


def plot_results(y_pred, y_true):
    
    # plot both distributions
    figure(figsize = (10, 8))
    plt.hist(y_pred, bins = 100, alpha = 0.5, label = "Predicted")
    plt.hist(y_true, bins = 100, alpha = 0.5, label = "True")
    plt.legend(loc = "upper right")
    plt.title("Predicted vs True Distributions")
    plt.show()

    # plot the predicted vs true
    figure(figsize = (10, 8))
    plt.scatter(y_pred, y_true)
    plt.title("Predicted vs True")
    plt.show()

# %% [markdown]
# ## Linear Regression

# %%
def LinearRegression_model(X_train_valid, y_train_valid, X_test, y_test):

    # define model
    model = LinearRegression()

    # fit the model
    model.fit(X_train_valid, y_train_valid)

    # predict on the test set
    y_pred = model.predict(X_test)
    
    # negative values are not allowed
    y_pred[y_pred < 0] = 0

    # compute the results
    train_results = compute_results(model.predict(X_train_valid), y_train_valid)
    test_results = compute_results(y_pred, y_test)

    # plot the results
    plot_results(y_pred, y_test)

    # store the results in the same dataframe
    results = pd.concat([train_results, test_results], axis = 0)
    # add a column with "training set" and "test set"
    results["set"] = ["train set", "test set"]
    # put this column in the first position
    results = results[["set", "mae", "mse", "rmse", "mape", "r2"]]

    print("Linear Regression Results: ")
    print(results)

    return model

# %%
Linear_model = LinearRegression_model(X_train_valid, y_train_valid, X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [34], line 1
# ----> 1 Linear_model = LinearRegression_model(X_train_valid, y_train_valid, X_test, y_test)
#
# Cell In [33], line 7, in LinearRegression_model(X_train_valid, y_train_valid, X_test, y_test)
#       4 model = LinearRegression()
#       6 # fit the model
# ----> 7 model.fit(X_train_valid, y_train_valid)
#       9 # predict on the test set
#      10 y_pred = model.predict(X_test)
#
# File ~/miniconda/lib/python3.9/site-packages/sklearn/linear_model/_base.py:684, in LinearRegression.fit(self, X, y, sample_weight)
#     680 n_jobs_ = self.n_jobs
#     682 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 684 X, y = self._validate_data(
#     685     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     686 )
#     688 sample_weight = _check_sample_weight(
#     689     sample_weight, X, dtype=X.dtype, only_non_negative=True
#     690 )
#     692 X, y, X_offset, y_offset, X_scale = _preprocess_data(
#     693     X,
#     694     y,
#    (...)
#     698     sample_weight=sample_weight,
#     699 )
#
# File ~/miniconda/lib/python3.9/site-packages/sklearn/base.py:596, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     594         y = check_array(y, input_name="y", **check_y_params)
#     595     else:
# --> 596         X, y = check_X_y(X, y, **check_params)
#     597     out = X, y
#     599 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~/miniconda/lib/python3.9/site-packages/sklearn/utils/validation.py:1074, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1069         estimator_name = _check_estimator_name(estimator)
#    1070     raise ValueError(
#    1071         f"{estimator_name} requires y to be passed, but the target y is None"
#    1072     )
# -> 1074 X = check_array(
#    1075     X,
#    1076     accept_sparse=accept_sparse,
#    1077     accept_large_sparse=accept_large_sparse,
#    1078     dtype=dtype,
#    1079     order=order,
#    1080     copy=copy,
#    1081     force_all_finite=force_all_finite,
#    1082     ensure_2d=ensure_2d,
#    1083     allow_nd=allow_nd,
#    1084     ensure_min_samples=ensure_min_samples,
#    1085     ensure_min_features=ensure_min_features,
#    1086     estimator=estimator,
#    1087     input_name="X",
#    1088 )
#    1090 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1092 check_consistent_length(X, y)
#
# File ~/miniconda/lib/python3.9/site-packages/sklearn/utils/validation.py:899, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     893         raise ValueError(
#     894             "Found array with dim %d. %s expected <= 2."
#     895             % (array.ndim, estimator_name)
#     896         )
#     898     if force_all_finite:
# --> 899         _assert_all_finite(
#     900             array,
#     901             input_name=input_name,
#     902             estimator_name=estimator_name,
#     903             allow_nan=force_all_finite == "allow-nan",
#     904         )
#     906 if ensure_min_samples > 0:
#     907     n_samples = _num_samples(array)
#
# File ~/miniconda/lib/python3.9/site-packages/sklearn/utils/validation.py:146, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     124         if (
#     125             not allow_nan
#     126             and estimator_name
#    (...)
#     130             # Improve the error message on how to handle missing values in
#     131             # scikit-learn.
#     132             msg_err += (
#     133                 f"\n{estimator_name} does not accept missing values"
#     134                 " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     144                 "#estimators-that-handle-nan-values"
#     145             )
# --> 146         raise ValueError(msg_err)
#     148 # for object dtype data, we only check for NaNs (GH-13254)
#     149 elif X.dtype == np.dtype("object") and not allow_nan:
#
# ValueError: Input X contains NaN.
# LinearRegression does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
# save the model
pickle.dump(Linear_model, open("Linear_model.pkl", "wb"))

# load the model
#Linear_model = pickle.load(open("Linear_model.pkl", "rb"))

# %% [markdown]
# ## Lasso Regression

# %%
def Lasso_model(X_train_valid, y_train_valid, X_test, y_test):

    # define model
    model = LassoCV(cv=5, random_state=0) # 5-fold cross validation to select the best alpha

    # fit the model
    model.fit(X_train_valid, y_train_valid)

    # predict on the test set
    y_pred = model.predict(X_test)

    # negative values are not allowed
    y_pred[y_pred < 0] = 0

    # compute the results
    train_results = compute_results(model.predict(X_train_valid), y_train_valid)
    test_results = compute_results(y_pred, y_test)

    # plot the results
    plot_results(y_pred, y_test)

    # store the results in the same dataframe
    results = pd.concat([train_results, test_results], axis = 0)
    # add a column with "training set" and "test set"
    results["set"] = ["train set", "test set"]
    # put this column in the first position
    results = results[["set", "mae", "mse", "rmse", "mape", "r2"]]

    print("Lasso Regression Results: ")
    print(results)

    return model

# %%
Lasso_model = Lasso_model(X_train_valid, y_train_valid, X_test, y_test)
# Out:
# Lasso Regression Results:
#          set       mae        mse      rmse      mape        r2
# 0  train set  1.493380  16.049276  4.006155  1.019334  0.670965
# 0   test set  1.567513  20.654812  4.544757  0.784181  0.664522

# %% [markdown]
# ## Random Forest

# %%
def RandomForest_model(X_train_valid, y_train_valid, X_test, y_test):

    # define model
    model = RandomForestRegressor(n_estimators = 200, random_state=0)

    # define parameters
    parameters = {"max_depth": [10, 15, 20],
                  "min_samples_split": [2, 5, 10],
                  "max_features": [10, 15, 20],
                  }

    # use random search to find the best parameters
    grid = RandomizedSearchCV(model, parameters, cv = 5, n_iter = 10, random_state = 0)

    # use only 10% of the data to speed up the computation
    X_train_valid = X_train_valid.sample(frac = 0.1, random_state = 0)
    y_train_valid = y_train_valid.sample(frac = 0.1, random_state = 0)
    X_test = X_test.sample(frac = 0.1, random_state = 0)
    y_test = y_test.sample(frac = 0.1, random_state = 0)

    # fit the model
    grid.fit(X_train_valid, y_train_valid)

    # predict on the test set
    y_pred = grid.predict(X_test)

    # negative values are not allowed
    y_pred[y_pred < 0] = 0

    # compute the results
    train_results = compute_results(grid.predict(X_train_valid), y_train_valid)
    test_results = compute_results(y_pred, y_test)

    # plot the results
    plot_results(y_pred, y_test)

    # store the results in the same dataframe
    results = pd.concat([train_results, test_results], axis = 0)
    # add a column with "training set" and "test set"
    results["set"] = ["train set", "test set"]
    # put this column in the first position
    results = results[["set", "mae", "mse", "rmse", "mape", "r2"]]

    print("Random Forest Results: ")
    print(results)

    # return results and model
    return grid.best_estimator_

# %%
RF_model = RandomForest_model(X_train_valid, y_train_valid, X_test, y_test)
# Out:
# Random Forest Results:
#          set       mae       mse      rmse      mape        r2
# 0  train set  0.221616  0.812446  0.901358  0.098753  0.985335
# 0   test set  0.712721  9.420981  3.069362  0.170862  0.874540

# %%
y_pred = RF_model.predict(X_test)

# compute the results
train_results = compute_results(RF_model.predict(X_train_valid), y_train_valid)
test_results = compute_results(y_pred, y_test)

# plot the results
plot_results(y_pred, y_test)

# store the results in the same dataframe
results = pd.concat([train_results, test_results], axis = 0)
# add a column with "training set" and "test set"
results["set"] = ["train set", "test set"]
# put this column in the first position
results = results[["set", "mae", "mse", "rmse", "mape", "r2"]]

results
# Out:
#          set       mae       mse      rmse     mape        r2
# 0  train set  0.539138  4.824902  2.196566  0.24616  0.901082
# 0   test set  0.604196  7.492135  2.737176  0.18604  0.878312

# %%
# print feature importance of the random forest model
importances = pd.DataFrame({"feature": X_train_valid.columns, "importance": RF_model.feature_importances_})
importances = importances.sort_values("importance", ascending = False)
importances
# Out:
#                         feature  importance
# 0                       overall    0.303548
# 1                     potential    0.149766
# 2                      wage_eur    0.134646
# 28           skill_ball_control    0.094411
# 32           movement_reactions    0.045456
# 22      attacking_short_passing    0.038601
# 15                      passing    0.034410
# 16                    dribbling    0.025563
# 42             mentality_vision    0.022434
# 24              skill_dribbling    0.013742
# 29        movement_acceleration    0.011126
# 3                           age    0.009604
# 14                     shooting    0.009132
# 31             movement_agility    0.008905
# 41        mentality_positioning    0.005719
# 25                  skill_curve    0.005696
# 19           attacking_crossing    0.005555
# 13                         pace    0.005292
# 44          mentality_composure    0.004608
# 30        movement_sprint_speed    0.004388
# 26            skill_fk_accuracy    0.004022
# 46    defending_standing_tackle    0.003421
# 33             movement_balance    0.003148
# 17                    defending    0.003134
# 27           skill_long_passing    0.003073
# 35                power_jumping    0.002943
# 34             power_shot_power    0.002898
# 21   attacking_heading_accuracy    0.002804
# 36                power_stamina    0.002747
# 8     club_contract_valid_until    0.002649
# 20          attacking_finishing    0.002574
# 5                     weight_kg    0.002518
# 43          mentality_penalties    0.002505
# 38             power_long_shots    0.002376
# 23            attacking_volleys    0.002337
# 18                       physic    0.002209
# 52         goalkeeping_reflexes    0.002201
# 40      mentality_interceptions    0.002094
# 47     defending_sliding_tackle    0.002003
# 4                     height_cm    0.001817
# 51      goalkeeping_positioning    0.001754
# 45  defending_marking_awareness    0.001733
# 39         mentality_aggression    0.001573
# 50          goalkeeping_kicking    0.001539
# 37               power_strength    0.001501
# 48           goalkeeping_diving    0.001487
# 49         goalkeeping_handling    0.001270
# 58            defense_work_rate    0.000699
# 9                preferred_foot    0.000439
# 11                  skill_moves    0.000432
# 10                    weak_foot    0.000418
# 12     international_reputation    0.000360
# 56                   position_M    0.000292
# 57             attack_work_rate    0.000218
# 53                   position_A    0.000103
# 54                   position_D    0.000072
# 6                  league_level    0.000032
# 7                   club_joined    0.000000
# 55                   position_G    0.000000

# %%
# save the model
pickle.dump(RF_model, open("RF_model.pkl", "wb"))

# load the model
#RF_model = pickle.load(open("RF_model.pkl", "rb"))

# %% [markdown]
# ## XGBoost

# %%
def XGBoost_model(X_train_valid, y_train_valid, X_test, y_test):

    #  define model
    model = XGBRegressor(n_estimators = 200, random_state=0)

    # define parameters
    parameters = {"max_depth": [4, 6, 10],
                  "alpha": [0, 0.1, 0.3],
                  "eta": [0.001, 0.1, 0.3],
                  }

    # define random search
    grid = RandomizedSearchCV(model, parameters, cv = 5, n_iter = 10, random_state = 0)

    # use only 10% of the data to speed up the computation
    X_train_valid = X_train_valid.sample(frac = 0.1, random_state = 0)
    y_train_valid = y_train_valid.sample(frac = 0.1, random_state = 0)
    X_test = X_test.sample(frac = 0.1, random_state = 0)
    y_test = y_test.sample(frac = 0.1, random_state = 0)

    # fit the model
    grid.fit(X_train_valid, y_train_valid)

    # predict on the test set
    y_pred = grid.predict(X_test)

    # negative values are not allowed
    y_pred[y_pred < 0] = 0

    # compute the results
    train_results = compute_results(grid.predict(X_train_valid), y_train_valid)
    test_results = compute_results(y_pred, y_test)

    # plot the results
    plot_results(y_pred, y_test)

    # store the results in the same dataframe
    results = pd.concat([train_results, test_results], axis = 0)
    # add a column with "training set" and "test set"
    results["set"] = ["train set", "test set"]
    # put this column in the first position
    results = results[["set", "mae", "mse", "rmse", "mape", "r2"]]

    print("XGBoost Results: ")
    print(results)

    return grid.best_estimator_

# %%
XGB_model = XGBoost_model(X_train_valid, y_train_valid, X_test, y_test)
# Out:
# XGBoost Results:
#          set       mae       mse      rmse      mape        r2
# 0  train set  0.077344  0.011311  0.106353  0.110499  0.999796
# 0   test set  0.593391  5.193168  2.278852  0.180871  0.930842

# %%
y_pred = XGB_model.predict(X_test)

# compute the results
train_results = compute_results(XGB_model.predict(X_train_valid), y_train_valid)
test_results = compute_results(y_pred, y_test)

# plot the results
plot_results(y_pred, y_test)

# store the results in the same dataframe
results = pd.concat([train_results, test_results], axis = 0)
# add a column with "training set" and "test set"
results["set"] = ["train set", "test set"]
# put this column in the first position
results = results[["set", "mae", "mse", "rmse", "mape", "r2"]]

results
# Out:
#          set       mae       mse      rmse      mape        r2
# 0  train set  0.495523  4.069560  2.017315  0.230905  0.916568
# 0   test set  0.513806  5.255883  2.292571  0.188003  0.914633

# %%
# save the model
#pickle.dump(XGB_model, open("XGB_model.pkl", "wb"))

# load the model
XGB_model = pickle.load(open("XGB_model.pkl", "rb"))

# %%
# print feature importance of the xgboost model
importances = pd.DataFrame({"feature": X_train_valid.columns, "importance": XGB_model.feature_importances_})
importances = importances.sort_values("importance", ascending = False)
importances
# Out:
#                         feature  importance
# 0                       overall    0.635352
# 1                     potential    0.084532
# 28           skill_ball_control    0.075631
# 4                     height_cm    0.036757
# 3                           age    0.016417
# 13                         pace    0.014218
# 42             mentality_vision    0.013004
# 58            defense_work_rate    0.012174
# 21   attacking_heading_accuracy    0.012112
# 41        mentality_positioning    0.012021
# 29        movement_acceleration    0.008591
# 5                     weight_kg    0.007580
# 14                     shooting    0.007464
# 24              skill_dribbling    0.006877
# 8     club_contract_valid_until    0.005692
# 52         goalkeeping_reflexes    0.004868
# 10                    weak_foot    0.004141
# 30        movement_sprint_speed    0.004069
# 22      attacking_short_passing    0.003825
# 25                  skill_curve    0.003031
# 20          attacking_finishing    0.002935
# 34             power_shot_power    0.002728
# 17                    defending    0.002404
# 2                      wage_eur    0.002219
# 43          mentality_penalties    0.002057
# 15                      passing    0.001770
# 12     international_reputation    0.001649
# 44          mentality_composure    0.001470
# 51      goalkeeping_positioning    0.001209
# 38             power_long_shots    0.001117
# 46    defending_standing_tackle    0.000952
# 47     defending_sliding_tackle    0.000951
# 26            skill_fk_accuracy    0.000872
# 31             movement_agility    0.000761
# 9                preferred_foot    0.000749
# 23            attacking_volleys    0.000748
# 33             movement_balance    0.000707
# 19           attacking_crossing    0.000529
# 36                power_stamina    0.000502
# 45  defending_marking_awareness    0.000487
# 32           movement_reactions    0.000479
# 18                       physic    0.000469
# 48           goalkeeping_diving    0.000455
# 54                   position_D    0.000374
# 40      mentality_interceptions    0.000352
# 50          goalkeeping_kicking    0.000350
# 39         mentality_aggression    0.000335
# 6                  league_level    0.000324
# 35                power_jumping    0.000320
# 49         goalkeeping_handling    0.000300
# 37               power_strength    0.000277
# 16                    dribbling    0.000250
# 27           skill_long_passing    0.000230
# 11                  skill_moves    0.000222
# 53                   position_A    0.000037
# 56                   position_M    0.000027
# 57             attack_work_rate    0.000026
# 7                   club_joined    0.000000
# 55                   position_G    0.000000

# %%
# keep only the features with an importance higher than 0.01
XGB_best_features = importances[importances["importance"] > 0.01]["feature"].values
XGB_best_features
# Out:
# array(['overall', 'potential', 'skill_ball_control', 'height_cm', 'age',
#        'pace', 'mentality_vision', 'defense_work_rate',
#        'attacking_heading_accuracy', 'mentality_positioning'],
#       dtype=object)

# %% [markdown]
# ## Interpretable Clustering

# %%
# Use datasets with only the best features from XGBoost
X_train_valid_xgb = X_train_valid[XGB_best_features]
X_test_xgb = X_test[XGB_best_features]

# %%
# use Elbow method and silhouette scoreto find the optimal number of clusters

def elbow_and_silhouette(X_train_valid, max_k, random_state = 0):
    scores = []
    inertia = []
    for k in tqdm(range(2, max_k + 1)):
        kmeans = KMeans(n_clusters = k, random_state = random_state)
        kmeans.fit(X_train_valid)
        inertia.append(kmeans.inertia_)
        scores.append(silhouette_score(X_train_valid, kmeans.labels_))

    plt.figure(figsize = (10, 5))
    plt.subplot(1, 2, 1)
    plt.plot(range(2, max_k + 1), inertia, marker = "o")
    plt.xlabel("Number of clusters")
    plt.ylabel("Inertia")
    plt.title("Elbow method")

    plt.subplot(1, 2, 2)
    plt.plot(range(2, max_k + 1), scores, marker = "o")
    plt.xlabel("Number of clusters")
    plt.ylabel("Silhouette score")
    plt.title("Silhouette score")

    plt.show()

elbow_and_silhouette(X_train_valid_xgb, 20)
# Out:
# 100%|██████████| 19/19 [02:45<00:00,  8.71s/it]
